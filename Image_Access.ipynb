# %% [markdown]
# # Searching for and retrieving images
#
# In this notebook, we show how to search for and retrieve images from VO services using the Registry and the __[Simple Image Access](http://www.ivoa.net/documents/SIA/)__ (SIA) protocol.
#
# * [1. Finding](#finding) SIA resources from the Registry
# * [2. Using](#sia) SIA to retrieve an image

# %% [markdown]
# ####  (Note:  for all of these notebooks, the results depend on real-time queries.  Sometimes there are problems, either because a given service has changed, is undergoing maintenance, or the internet connectivity is having problems, etc.  Always retry a couple of times, come back later and try again, and only then send us the problem report to investigate.)

# %%
## For debugging navo_utils.  TO BE REMOVED
# %load_ext autoreload
# %autoreload 2

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
import astropy
from IPython.display import Image as ipImage, display

## For development convenience, though it seems to make things error the second time a cell is run?
#%load_ext autoreload
#%autoreload 2

## NAVO utilities
from navo_utils.image import Image, ImageColumn
from navo_utils.registry import Registry

## For handling ordinary astropy Tables
from astropy.table import Table

## For reading FITS files
import astropy.io.fits as apfits

## For pretty displays
import aplpy

## There are a number of relatively unimportant warnings that 
## show up, so for now, suppress them:
import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# <a id="finding"></a>
#
# # 1.  Finding SIA resources from the Registry
#
# First, how do we find out what  services are available?  These are listed in a registry at STScI (__[see here](http://www.ivoa.net/documents/RegTAP/)__).  Our Registry function gives a simple interface for how to search for services.
#
# Let's search for services providing images in the ultraviolet bands:

# %%
uv_tables=Registry.query(service_type='image',waveband='uv')
## Sometimes strange behavior with this now
uv_tables.show_in_notebook()
#uv_tables
#uv_tables.info
# Out:
# ...

# %% [markdown]
# This returns an astropy table containing information about the services available.  We can then specify the service we want by using the "access_url" entry in the corresponding row.  We'll repeat the search with additional qualifiers to isolate the row we want:

# %%
## In the keyword search, the "%" character is a wild card.
uv_tables=Registry.query(service_type='image',waveband='uv',keyword='swiftuvot')
uv_tables
# Out:
# <Table masked=True length=1>
#  waveband  short_name ...     publisher        service_type
# unicode10   unicode9  ...     unicode17         unicode17
# ---------- ---------- ... ----------------- -----------------
# uv#optical  SWIFTUVOT ... NASA/GSFC HEASARC simpleimageaccess

# %% [markdown]
# This shows us that the data we are interested in comes from the HEASARC's SkyView service, but the point of these VO tools is that you don't need to know that ahead of time or indeed to care where it comes from.

# %% [markdown]
# <a id="sia"></a>
#
# # 2. Using SIA to retrieve an image:
#
# Now we look for images of our favorite source.  See __[the SIA definition](http://www.ivoa.net/documents/WD/SIA/sia-20040524.html)__ for usage.  In short, you can specify the central position (POS), the angular SIZE, and the NAXIS, i.e., the number of bins.  It is up to the service to determine how to provide this.  SkyView, for example, will mosaic/bin/interpolate as needed from the archive data.
#
# What is returned to you is not the image itself but a list of images available and how to access them.  This is easiest shown by example:

# %%
pos='202.469575,47.195258'
im_table=Image.query(service=uv_tables[0],coords=pos,radius=0.2)
im_table[0]
# Out:
# <ImageTable masked=True length=12>
#      Survey          Ra     ... LogicalName
#    unicode16      float64   ...   unicode1
# ---------------- ---------- ... -----------
#    swiftuvotvint 202.469575 ...           1
#    swiftuvotvint 202.469575 ...           1
#    swiftuvotbint 202.469575 ...           2
#    swiftuvotbint 202.469575 ...           2
#    swiftuvotuint 202.469575 ...           3
#    swiftuvotuint 202.469575 ...           3
# swiftuvotuvw1int 202.469575 ...           4
# swiftuvotuvw1int 202.469575 ...           4
# swiftuvotuvw2int 202.469575 ...           5
# swiftuvotuvw2int 202.469575 ...           5
# swiftuvotuvm2int 202.469575 ...           6
# swiftuvotuvm2int 202.469575 ...           6

# %% [markdown]
# Extract the fields you're interested in, e.g., the URLs of the images made by skyview.  Note that specifying as we did SwiftUVOT, we get a number of different images, e.g., UVOT U, V, B, W1, W2, etc.  For each survey, there are two URLs, first the FITS IMAGE and second the JPEG.
#
# Note that different services will return different column names, but all will have a column giving the URL to access the image.  The ImageColumn class can be used to extract the correct column without having to know what the individual services call it;  you can always ask for the column given by ImageColumn.ACCESS_URL.

# %%
row_fits=0 # You see above that even-numbered rows are the JPEGs, the next the corresponding FITS
row_jpeg=row_fits+1
###  Inside the table is a numpy record array that you can access like this, for example:
###  (for the 0th object result, the 7th row, the 8th column)
#print(table.array[0][7][8])
#  Or like this
print(im_table[0][row_fits][ImageColumn.ACCESS_URL])
### To download the FITS image itself:
print(im_table[0][row_jpeg][ImageColumn.ACCESS_URL])
# Out:
# https://skyview.gsfc.nasa.gov/cgi-bin/images?position=202.469575%2C47.1952583&survey=swiftuvotvint&pixels=300%2C300&sampler=LI&size=0.4000000000000001%2C0.4000000000000001&projection=Tan&coordinates=J2000.0&requestID=skv1540491650575&return=FITS
# https://skyview.gsfc.nasa.gov/cgi-bin/images?position=202.469575%2C47.1952583&survey=swiftuvotvint&pixels=300%2C300&sampler=LI&size=0.4000000000000001%2C0.4000000000000001&projection=Tan&coordinates=J2000.0&requestID=skv1540491650575&nofits=1&quicklook=jpeg&return=jpeg

# %% [markdown]
# ### Resulting image
# Since we can see that the second row is a JPEG, we can display it in python easily.
#
# Again, we can use the ImageColumn utility to check the format.  Whatever the service calls the format column, We can check it with ImageColumn.FORMAT.

# %%
if (im_table[0][row_jpeg][ImageColumn.FORMAT] == "image/jpeg"):
    display(Image.get_image(im_table[0][row_jpeg]))

# %% [markdown]
# Or download the FITS image and display it with:
#
# (This often errors off with a time out message.  Just try it again, possibly a couple of times.)

# %%
hdu_list=Image.get_fits(im_table[0][row_fits])

# %%
im_table[0][row_fits]
# Out:
# <ImRow index=0 masked=True>
#     Survey        Ra        Dec      Dim     Size                       Scale                        Format   PixFlags                                                                                                                          URL                                                                                                                          LogicalName
#   unicode16    float64    float64   int32   object                      object                     unicode10  unicode1                                                                                                                       unicode272                                                                                                                        unicode1
# ------------- ---------- ---------- ----- --------- ---------------------------------------------- ---------- -------- ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- -----------
# swiftuvotvint 202.469575 47.1952583     2 [300 300] [-0.0013333333333333335 0.0013333333333333335] image/fits        F https://skyview.gsfc.nasa.gov/cgi-bin/images?position=202.469575%2C47.1952583&survey=swiftuvotvint&pixels=300%2C300&sampler=LI&size=0.4000000000000001%2C0.4000000000000001&projection=Tan&coordinates=J2000.0&requestID=skv1540491650575&return=FITS           1

# %%
plt.imshow(hdu_list[0].data, cmap='gray', origin='lower',vmax=0.1)

# %% [markdown]
# ### Now with aplpy
#
# This package knows how to read the header keywords in WCS to display the correct coordinate axes.

# %%
gc = aplpy.FITSFigure(hdu_list,figsize=(4, 4))
gc.show_grayscale(stretch='log', vmax=0.1)
# Out:
# INFO: Auto-setting vmin to  7.026e-03 [aplpy.core]

# %% [markdown]
# ### A related example with several services offering the same data:
# Suppose we want SDSS data.  A generic query finds us a number of possibilities:

# %%
cat_table=Registry.query(service_type='image',keyword='sdss',waveband='optical')
cat_table
# Out:
# <Table masked=True length=17>
# waveband   short_name  ...          publisher              service_type
# unicode7   unicode13   ...          unicode28               unicode17
# -------- ------------- ... ---------------------------- -----------------
#  optical       SDSSDR2 ... The Johns Hopkins University simpleimageaccess
#  optical       SDSSDR1 ... The Johns Hopkins University simpleimageaccess
#  optical       SDSSDR7 ... The Johns Hopkins University simpleimageaccess
#  optical       SDSSDR8 ... The Johns Hopkins University simpleimageaccess
#  optical       SDSSDR9 ... The Johns Hopkins University simpleimageaccess
#  optical     SDSS SIAP ... The Johns Hopkins University simpleimageaccess
#  optical       SDSSDR5 ... The Johns Hopkins University simpleimageaccess
#  optical SDSSDR3-Color ...     The Johns Hopkins Univer simpleimageaccess
#  optical     SDSSDR3-G ...     The Johns Hopkins Univer simpleimageaccess
#  optical     SDSSDR3-I ...     The Johns Hopkins Univer simpleimageaccess
#  optical     SDSSDR3-R ...     The Johns Hopkins Univer simpleimageaccess
#  optical     SDSSDR3-U ... The Johns Hopkins University simpleimageaccess
#  optical     SDSSDR3-Z ...     The Johns Hopkins Univer simpleimageaccess
#  optical SDSSDR4-Color ...     The Johns Hopkins Univer simpleimageaccess
#  optical       SDSSDR4 ...     The Johns Hopkins Univer simpleimageaccess
#  optical          SDSS ...            NASA/GSFC HEASARC simpleimageaccess
#  optical       SDSSDR7 ...            NASA/GSFC HEASARC simpleimageaccess

# %%
#  numpy makes it easy to select the rows of a table where a column has a given value:  
cat_dr7 = cat_table[np.isin(cat_table['short_name'], 
                                    ['SDSSDR7'])]
cat_dr7['short_name', 'access_url']
# Out:
# <Table masked=True length=2>
# short_name ...
# unicode13  ...
# ---------- ...
#    SDSSDR7 ...
#    SDSSDR7 ...

# %%
sdss_table=Image.query(cat_dr7[0],coords=pos,radius=0.1)
sdss_table[0]
# Out:
# <ImageTable masked=True length=30>
#                Title                ...
#              unicode35              ...
# ----------------------------------- ...
# Sloan Digital Sky Survey - Filter u ...
# Sloan Digital Sky Survey - Filter g ...
# Sloan Digital Sky Survey - Filter r ...
# Sloan Digital Sky Survey - Filter i ...
# Sloan Digital Sky Survey - Filter z ...
# Sloan Digital Sky Survey - Filter u ...
# Sloan Digital Sky Survey - Filter g ...
# Sloan Digital Sky Survey - Filter r ...
# Sloan Digital Sky Survey - Filter i ...
# Sloan Digital Sky Survey - Filter z ...
#                                 ... ...
# Sloan Digital Sky Survey - Filter u ...
# Sloan Digital Sky Survey - Filter g ...
# Sloan Digital Sky Survey - Filter r ...
# Sloan Digital Sky Survey - Filter i ...
# Sloan Digital Sky Survey - Filter z ...
# Sloan Digital Sky Survey - Filter u ...
# Sloan Digital Sky Survey - Filter g ...
# Sloan Digital Sky Survey - Filter r ...
# Sloan Digital Sky Survey - Filter i ...
# Sloan Digital Sky Survey - Filter z ...

# %% [markdown]
# So one of these is served by SDSS's SkyServer and the other by HEASARC's SkyView.  The SIA service at SkyServer returns the following image:

# %%
pos='202.469575,47.195258'
sdss_table=Image.query(cat_dr7[0],coords=pos,radius=0.1)
#  Download the FITS image:
Image.get_fits(sdss_table[0][0],filename='downloads/sdssdr7_image.fits')
hdu_list=apfits.open('downloads/sdssdr7_image.fits')
gc = aplpy.FITSFigure(hdu_list,figsize=(5, 5))
gc.show_grayscale(stretch='log', vmax=1050,vmin=1010)
#plt.imshow(hdu_list[0].data, cmap='gray', origin='lower',vmax=1100,vmin=1010) #040,vmin=1000)
# Out:
# FITS image written to downloads/sdssdr7_image.fits
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]

# %%
#import pdb; pdb.set_trace()
sdss_table=Image.query(cat_dr7[0],coords=pos,radius=0.1)

# %% [markdown]
# The SkyView service returns this one processed slightly differently:

# %% [markdown]
# ###  Looks like SkyServer isn't centering, and it looks sideways to me!  And why is the scaling different?  The SkyServer appears to be getting one of the two images SkyView is mosaic'ing together;  you can see the boundary below.

# %% [markdown]
# (Note:  committing this version despite below error, which is because skyview is being hammered.  To be fixed later.)

# %%
sv_table=Image.query(cat_dr7[1],coords=pos,radius=0.1)
gc=aplpy.FITSFigure( Image.get_fits(sv_table[0][0]), figsize=(5,5) )
gc.show_grayscale(stretch='log', vmax=1300,vmin=1010)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-21-89b6894cea9c> in <module>()
#       1 sv_table=Image.query(cat_dr7[1],coords=pos,radius=0.1)
# ----> 2 gc=aplpy.FITSFigure( Image.get_fits(sv_table[0][0]), figsize=(5,5) )
#       3 gc.show_grayscale(stretch='log', vmax=1300,vmin=1010)
#
# /Users/tjaffe/space/sw/heasarc/nasa-navo/workshop-dev/navo_utils/image.pyc in get_fits(self, row_or_url, filename)
#     192            from astropy.io import fits
#     193            import os
# --> 194            im=fits.open(savename)
#     195            os.remove(savename)
#     196            return im
#
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     146
#     147     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 148                             lazy_load_hdus, **kwargs)
#     149
#     150
#
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     397         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     398                              save_backup=save_backup, cache=cache,
# --> 399                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#     400
#     401     @classmethod
#
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in _readfrom(cls, fileobj, data, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#    1010
#    1011         # Make sure at least the PRIMARY HDU can be read
# -> 1012         read_one = hdulist._read_next_hdu()
#    1013
#    1014         # If we're trying to read only and no header units were found,
#
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in _read_next_hdu(self)
#    1085                                 fileobj.seek(offset, os.SEEK_SET)
#    1086
# -> 1087                         hdu = _BaseHDU.readfrom(fileobj, **kwargs)
#    1088                     except EOFError:
#    1089                         self._read_all = True
#
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/astropy/io/fits/hdu/base.pyc in readfrom(cls, fileobj, checksum, ignore_missing_end, **kwargs)
#     330         hdu = cls._readfrom_internal(fileobj, checksum=checksum,
#     331                                      ignore_missing_end=ignore_missing_end,
# --> 332                                      **kwargs)
#     333
#     334         # If the checksum had to be checked the data may have already been read
#
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/astropy/io/fits/hdu/base.pyc in _readfrom_internal(cls, data, header, checksum, ignore_missing_end, **kwargs)
#     395             if header is None:
#     396                 header_offset = data.tell()
# --> 397                 header = Header.fromfile(data, endcard=not ignore_missing_end)
#     398             hdu_fileobj = data
#     399             data_offset = data.tell()  # *after* reading the header
#
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/astropy/io/fits/header.pyc in fromfile(cls, fileobj, sep, endcard, padding)
#     447
#     448             return cls._from_blocks(block_iter, is_binary, sep, endcard,
# --> 449                                     padding)[1]
#     450         finally:
#     451             if close_file:
#
# /Users/tjaffe/anaconda3/envs/navo-py2/lib/python2.7/site-packages/astropy/io/fits/header.pyc in _from_blocks(cls, block_iter, is_binary, sep, endcard, padding)
#     516             # TODO: Pass this error to validation framework as an ERROR,
#     517             # rather than raising an exception
# --> 518             raise IOError('Header missing END card.')
#     519
#     520         header_str = ''.join(read_blocks)
#
# IOError: Header missing END card.

# %% [markdown]
# But it turns out that SkyView is just getting it by using the SIAP internally to get the data from the SDSS service.  The point of the VO protocols is that you don't need to know where the data are coming from.
